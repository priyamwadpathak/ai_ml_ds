# %% [markdown]
# ## Pandas Practice

# %%
import pandas as pd

# %%
colours = pd.Series(["Red", "White", "Green"])

# %%
colours
# Out:
# 0      Red
# 1    White
# 2    Green
# dtype: object

# %%
car_types = pd.Series(["Jaguar", "BMW", "Land Rover"])

# %%
car_types
# Out:
# 0        Jaguar
# 1           BMW
# 2    Land Rover
# dtype: object

# %%
df = pd.DataFrame({"Colours": colours, "Car types": car_types})

# %%
df
# Out:
#   Colours   Car types
# 0     Red      Jaguar
# 1   White         BMW
# 2   Green  Land Rover

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_car_sales_exercise.csv", index=False)

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
nums = pd.Series([1,2,3,4,5])
nums.mean(numeric_only=True)
# Out:
# np.float64(3.0)

# %%
nums.sum()
# Out:
# np.int64(15)

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales["Odometer (KM)"].mean(numeric_only=True)
# Out:
# np.float64(78601.4)

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
# IMP
car_sales["Price"].replace(r'[\$,]', '', regex=True).astype(float).round().astype(int)
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
car_sales["Price"] = car_sales["Price"].replace(r'[\$,]', '', regex=True).astype(float).round().astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing_data = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_data["Odometer"] = car_sales_missing_data["Odometer"].fillna(car_sales_missing_data["Odometer"].mean(numeric_only=True))

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_data.dropna(inplace=True)

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales["Seats"] = 5

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000      5
# 1   honda    Red          87899      4   5000      5
# 2  toyota   Blue          32549      3   7000      5
# 3     bmw  Black          11179      5  22000      5
# 4  nissan  White         213095      4   3500      5
# 5  toyota  Green          99213      4   4500      5
# 6   honda   Blue          45698      4   7500      5
# 7   honda   Blue          54738      4   7000      5
# 8  toyota  White          60000      4   6250      5
# 9  nissan  White          31600      4   9700      5

# %%
engine_sizes = [1.3, 2.4, 3.5, 4.2, 3.0, 2.6, 1.9, 3.9, 2.8, 1.4]
car_sales["Engine Size"] = engine_sizes

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          2.4
# 2  toyota   Blue          32549      3   7000      5          3.5
# 3     bmw  Black          11179      5  22000      5          4.2
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.6
# 6   honda   Blue          45698      4   7500      5          1.9
# 7   honda   Blue          54738      4   7000      5          3.9
# 8  toyota  White          60000      4   6250      5          2.8
# 9  nissan  White          31600      4   9700      5          1.4

# %%
car_sales["Price per KM"] = 10.0
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          2.4
# 2  toyota   Blue          32549      3   7000      5          3.5
# 3     bmw  Black          11179      5  22000      5          4.2
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.6
# 6   honda   Blue          45698      4   7500      5          1.9
# 7   honda   Blue          54738      4   7000      5          3.9
# 8  toyota  White          60000      4   6250      5          2.8
# 9  nissan  White          31600      4   9700      5          1.4
#
#    Price per KM
# 0          10.0
# 1          10.0
# 2          10.0
# 3          10.0
# 4          10.0
# 5          10.0
# 6          10.0
# 7          10.0
# 8          10.0
# 9          10.0

# %%
car_sales.drop(["Price per KM"], axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          2.4
# 2  toyota   Blue          32549      3   7000      5          3.5
# 3     bmw  Black          11179      5  22000      5          4.2
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.6
# 6   honda   Blue          45698      4   7500      5          1.9
# 7   honda   Blue          54738      4   7000      5          3.9
# 8  toyota  White          60000      4   6250      5          2.8
# 9  nissan  White          31600      4   9700      5          1.4

# %%
shuffled_car_sales = car_sales.sample(frac=1)
shuffled_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 6   honda   Blue          45698      4   7500      5          1.9
# 7   honda   Blue          54738      4   7000      5          3.9
# 1   honda    Red          87899      4   5000      5          2.4
# 9  nissan  White          31600      4   9700      5          1.4
# 8  toyota  White          60000      4   6250      5          2.8
# 3     bmw  Black          11179      5  22000      5          4.2
# 0  toyota  White         150043      4   4000      5          1.3
# 5  toyota  Green          99213      4   4500      5          2.6
# 2  toyota   Blue          32549      3   7000      5          3.5
# 4  nissan  White         213095      4   3500      5          3.0
#
#    Price per KM
# 6          10.0
# 7          10.0
# 1          10.0
# 9          10.0
# 8          10.0
# 3          10.0
# 0          10.0
# 5          10.0
# 2          10.0
# 4          10.0

# %%
shuffled_car_sales.reset_index(drop=True, inplace=True)

# %%
shuffled_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0   honda   Blue          45698      4   7500      5          1.9
# 1   honda   Blue          54738      4   7000      5          3.9
# 2   honda    Red          87899      4   5000      5          2.4
# 3  nissan  White          31600      4   9700      5          1.4
# 4  toyota  White          60000      4   6250      5          2.8
# 5     bmw  Black          11179      5  22000      5          4.2
# 6  toyota  White         150043      4   4000      5          1.3
# 7  toyota  Green          99213      4   4500      5          2.6
# 8  toyota   Blue          32549      3   7000      5          3.5
# 9  nissan  White         213095      4   3500      5          3.0
#
#    Price per KM
# 0          10.0
# 1          10.0
# 2          10.0
# 3          10.0
# 4          10.0
# 5          10.0
# 6          10.0
# 7          10.0
# 8          10.0
# 9          10.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         150043      4   4000      5          1.3
# 1   honda    Red          87899      4   5000      5          2.4
# 2  toyota   Blue          32549      3   7000      5          3.5
# 3     bmw  Black          11179      5  22000      5          4.2
# 4  nissan  White         213095      4   3500      5          3.0
# 5  toyota  Green          99213      4   4500      5          2.6
# 6   honda   Blue          45698      4   7500      5          1.9
# 7   honda   Blue          54738      4   7000      5          3.9
# 8  toyota  White          60000      4   6250      5          2.8
# 9  nissan  White          31600      4   9700      5          1.4
#
#    Price per KM
# 0          10.0
# 1          10.0
# 2          10.0
# 3          10.0
# 4          10.0
# 5          10.0
# 6          10.0
# 7          10.0
# 8          10.0
# 9          10.0

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White      93776.875      4   4000      5          1.3
# 1   honda    Red      54936.875      4   5000      5          2.4
# 2  toyota   Blue      20343.125      3   7000      5          3.5
# 3     bmw  Black       6986.875      5  22000      5          4.2
# 4  nissan  White     133184.375      4   3500      5          3.0
# 5  toyota  Green      62008.125      4   4500      5          2.6
# 6   honda   Blue      28561.250      4   7500      5          1.9
# 7   honda   Blue      34211.250      4   7000      5          3.9
# 8  toyota  White      37500.000      4   6250      5          2.8
# 9  nissan  White      19750.000      4   9700      5          1.4
#
#    Price per KM
# 0          10.0
# 1          10.0
# 2          10.0
# 3          10.0
# 4          10.0
# 5          10.0
# 6          10.0
# 7          10.0
# 8          10.0
# 9          10.0

# %%
car_sales.rename(columns={"Odometer (KM)": "Odometer (Miles)"}, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price  Seats  Engine Size  \
# 0  toyota  White         93776.875      4   4000      5          1.3
# 1   honda    Red         54936.875      4   5000      5          2.4
# 2  toyota   Blue         20343.125      3   7000      5          3.5
# 3     bmw  Black          6986.875      5  22000      5          4.2
# 4  nissan  White        133184.375      4   3500      5          3.0
# 5  toyota  Green         62008.125      4   4500      5          2.6
# 6   honda   Blue         28561.250      4   7500      5          1.9
# 7   honda   Blue         34211.250      4   7000      5          3.9
# 8  toyota  White         37500.000      4   6250      5          2.8
# 9  nissan  White         19750.000      4   9700      5          1.4
#
#    Price per KM
# 0          10.0
# 1          10.0
# 2          10.0
# 3          10.0
# 4          10.0
# 5          10.0
# 6          10.0
# 7          10.0
# 8          10.0
# 9          10.0
